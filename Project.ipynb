# %% [markdown]
# # Reading the dataset

# %%
import pandas as pd
star_wars = pd.read_csv("star_wars.csv", encoding="ISO-8859-1")
print(star_wars.columns)
star_wars.head(10)
# Out:
# Index(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %% [markdown]
# ## Manupulating Data By Mapping And Renaming Column Names

# %%
yes_no = {
    'Yes' : True,
    'No' : False
}

for col in ['Have you seen any of the 6 films in the Star Wars franchise?', 'Do you consider yourself to be a fan of the Star Wars film franchise?']:
    star_wars[col] = star_wars[col].map(yes_no)

print(star_wars.head())
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#   Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0           Star Wars: Episode I  The Phantom Menace
# 1                                                NaN
# ...

# %%
import numpy as np
movie_mapping = {
    'Star Wars: Episode I  The Phantom Menace' : True,
    'Star Wars: Episode II  Attack of the Clones' : True,
    'Star Wars: Episode III  Revenge of the Sith' : True,
    'Star Wars: Episode IV  A New Hope' : True,
    'Star Wars: Episode V The Empire Strikes Back' : True,
    'Star Wars: Episode VI Return of the Jedi' : True,
    np.nan : False
}
for col in star_wars.columns[3:9]:
    star_wars[col] = star_wars[col].map(movie_mapping)
star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    Which of the following Star Wars films have you seen? Please select all that apply.  \
# 0                                               True
# 1                                              False
# ...

# %%
star_wars = star_wars.rename(columns = {
        "Which of the following Star Wars films have you seen? Please select all that apply.": "seen_1",
        "Unnamed: 4": "seen_2",
        "Unnamed: 5": "seen_3",
        "Unnamed: 6": "seen_4",
        "Unnamed: 7": "seen_5",
        "Unnamed: 8": "seen_6"
})
star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  \
# 0    True    True    True    True    True    True
# 1   False   False   False   False   False   False
# 2    True    True    True   False   False   False
# ...

# %%
#star_wars[star_wars.columns[9:15]] = star_wars[star_wars.columns[9:15]].astype(float)
star_wars = star_wars.rename(columns={
        "Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.": "ranking_1",
        "Unnamed: 10": "ranking_2",
        "Unnamed: 11": "ranking_3",
        "Unnamed: 12": "ranking_4",
        "Unnamed: 13": "ranking_5",
        "Unnamed: 14": "ranking_6"
        })

star_wars.head()
# Out:
#    RespondentID  Have you seen any of the 6 films in the Star Wars franchise?  \
# 0    3292879998                                               True
# 1    3292879538                                              False
# 2    3292765271                                               True
# 3    3292763116                                               True
# 4    3292731220                                               True
#
#   Do you consider yourself to be a fan of the Star Wars film franchise?  \
# 0                                               True
# 1                                                NaN
# 2                                              False
# 3                                               True
# 4                                               True
#
#    seen_1  seen_2  seen_3  seen_4  seen_5  seen_6  ranking_1  ...  \
# 0    True    True    True    True    True    True        3.0  ...
# 1   False   False   False   False   False   False        NaN  ...
# ...

# %% [markdown]
# ## Movie Rankings

# %%
mean_rankings = star_wars[star_wars.columns[9:15]].mean()
mean_rankings
# Out:
# ranking_1    3.732934
# ranking_2    4.087321
# ranking_3    4.341317
# ranking_4    3.272727
# ranking_5    2.513158
# ranking_6    3.047847
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.bar(range(6), mean_rankings)
#mean_rankings.plot.bar()
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# So far, we've cleaned up the data, renamed several columns, and computed the average ranking of each movie. As I suspected, it looks like the "original" movies are rated much more highly than the newer ones.

# %% [markdown]
# ## Movie Counts

# %%
sum_seen = star_wars[star_wars.columns[3:9]].sum()
sum_seen
# Out:
# seen_1    673
# seen_2    571
# seen_3    550
# seen_4    607
# seen_5    758
# seen_6    738
# dtype: int64

# %%
sum_seen.plot.bar(rot = 0) #This is better way to call above function but above one has thicker bars

# %% [markdown]
# It appears that the original movies were seen by more respondents than the newer movies. This reinforces what we saw in the rankings, where the earlier movies seem to be more popular.

# %% [markdown]
# ## Splitting Favourite Movies Into groups

# %%
# you can also split dataframe into two groups based on other
# binary columns like "Do you consider yourself to be a fan
# of the Star Wars film franchise? — True or False"
males = star_wars[star_wars["Gender"] == "Male"]
females = star_wars[star_wars["Gender"] == "Female"]

male_mean_rankings = males[males.columns[9:15]].mean()
female_mean_rankings = females[females.columns[9:15]].mean()
male_mean_rankings.plot.bar(rot = 0, title = 'Favourite Movies Of Males')
plt.show()
female_mean_rankings.plot.bar(rot = 0, title = 'Favourite Movies Of Females')
plt.show()

# %% [markdown]
# ## Splitting Seen Movie counts into groups

# %%
male_sum_seen = males[males.columns[3:9]].sum()
female_sum_seen = females[females.columns[3:9]].sum()
male_sum_seen.plot.bar(rot = 0, title = 'Movies Seen By Males')
plt.show()
female_sum_seen.plot.bar(rot = 0, title = 'Movies Seen By Females')
plt.show()

# %% [markdown]
# ## Male/Female differences in favorite Star Wars movie and most seen movie
#
# My conclusion: Interestingly, more males watches episode 1 and 2 than females but males liked it far less than females did.
